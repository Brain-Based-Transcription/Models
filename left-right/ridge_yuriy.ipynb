# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler
from sklearn.linear_model import RidgeClassifierCV
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score
from yuriy_preprocess import get_yuriy_data
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
X, Y, meta_data = get_yuriy_data(samples_around=100)

print(X.shape)
print(Y.shape)
print(meta_data)
# Out:
# (1388, 200, 19)
# (1388,)
# {'id': '201512101936.D091BB44', 'tag': 'NK-data import (auto)', 'sampFreq': 200, 'num_samples': 285800, 'channel_names': array(['Fp1', 'Fp2', 'F3', 'F4', 'C3', 'C4', 'P3', 'P4', 'O1', 'O2', 'F7',
#        'F8', 'T3', 'T4', 'T5', 'T6', 'Fz', 'Cz', 'Pz'], dtype='<U3'), 'binsuV': 1}

# %%
# Split data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1110, 200, 19)
# (278, 200, 19)
# (1110,)
# (278,)

# %%
import warnings
warnings.filterwarnings('ignore')

n_trials, n_t, n_ch = X.shape
latencies = np.arange(n_t)
alphas = np.logspace(-2, 8, 11)

ridge_pipe = make_pipeline(
      RobustScaler(),
      RidgeClassifierCV(alphas=alphas,
                        cv=StratifiedKFold(n_splits=20, shuffle=True, random_state=0),
                        scoring='balanced_accuracy',
                        fit_intercept=True)
)

best_lat, best_score = None, 0
all_scores = {}
for t in latencies:
    print(f"Processing latency {t}", end=" ")
    X_t = X_train[:, t, :]
    # Add error handling and validation
    try:
        cv_scores = cross_val_score(ridge_pipe, X_t, y_train,
                                    cv=StratifiedKFold(n_splits=5, shuffle=True, random_state=1),
                                    scoring='balanced_accuracy',
                                    n_jobs=-1)
        all_scores[t] = cv_scores
        mean_bacc = cv_scores.mean()
        print(f" mean_bacc: {mean_bacc}")
        if mean_bacc > best_score:
            best_score, best_lat = mean_bacc, t
            print(f"  New best score found: {mean_bacc:.3f}")
    except Exception as e:
        print(f"  Error processing time point {t}: {str(e)}")
        continue

print("\nResults Summary:")
print(f"Best latency: {best_lat}")
print(f"Relative to press: {(best_lat - (n_t//2)) / 200:.4f} s")
print(f"Cross-validation balanced accuracy: {best_score:.3f}")
# Out:
# Processing latency 0  mean_bacc: 0.525234438984439
#   New best score found: 0.525
# Processing latency 1  mean_bacc: 0.5360370597870598
#   New best score found: 0.536
# Processing latency 2  mean_bacc: 0.5485111735111735
#   New best score found: 0.549
# Processing latency 3  mean_bacc: 0.5477323914823915
# Processing latency 4  mean_bacc: 0.5594610682110682
#   New best score found: 0.559
# Processing latency 5  mean_bacc: 0.5405167017667016
# Processing latency 6  mean_bacc: 0.5243161343161342
# Processing latency 7  mean_bacc: 0.5405493155493156
# Processing latency 8  mean_bacc: 0.543227886977887
# Processing latency 9  mean_bacc: 0.5324243886743887
# Processing latency 10  mean_bacc: 0.5198521411021411
# Processing latency 11  mean_bacc: 0.5260698198198198
# Processing latency 12  mean_bacc: 0.5360285772785772
# Processing latency 13  mean_bacc: 0.5413775301275301
# Processing latency 14  mean_bacc: 0.548519656019656
# Processing latency 15  mean_bacc: 0.5342352579852581
# Processing latency 16  mean_bacc: 0.5395764595764596
# Processing latency 17  mean_bacc: 0.5423266935766936
# Processing latency 18  mean_bacc: 0.5467336492336492
# Processing latency 19  mean_bacc: 0.5450383175383176
# Processing latency 20  mean_bacc: 0.523246021996022
# Processing latency 21  mean_bacc: 0.5251538551538552
# Processing latency 22  mean_bacc: 0.521459868959869
# Processing latency 23  mean_bacc: 0.5305178717678718
# Processing latency 24  mean_bacc: 0.5322387972387972
# Processing latency 25  mean_bacc: 0.5359317596817597
# Processing latency 26  mean_bacc: 0.534251638001638
# Processing latency 27  mean_bacc: 0.5450138937638938
# Processing latency 28  mean_bacc: 0.5249827424827425
# Processing latency 29  mean_bacc: 0.5119793494793495
# Processing latency 30  mean_bacc: 0.5051540014040014
# Processing latency 31  mean_bacc: 0.516062361062361
# Processing latency 32  mean_bacc: 0.538536621036621
# Processing latency 33  mean_bacc: 0.5214275476775476
# Processing latency 34  mean_bacc: 0.5332537732537732
# Processing latency 35  mean_bacc: 0.5144391306891307
# Processing latency 36  mean_bacc: 0.5422542997542998
# Processing latency 37  mean_bacc: 0.5495264420264421
# Processing latency 38  mean_bacc: 0.5359964022464022
# Processing latency 39  mean_bacc: 0.5521488533988534
# Processing latency 40  mean_bacc: 0.5575861413361413
# Processing latency 41  mean_bacc: 0.5161110623610623
# Processing latency 42  mean_bacc: 0.5556701181701181
# Processing latency 43  mean_bacc: 0.5430327892827892
# Processing latency 44  mean_bacc: 0.5043913068913068
# Processing latency 45  mean_bacc: 0.5278549491049491
# Processing latency 46  mean_bacc: 0.5532113607113607
# Processing latency 47  mean_bacc: 0.5512064174564174
# Processing latency 48  mean_bacc: 0.5565711653211654
# Processing latency 49  mean_bacc: 0.5486904761904763
# Processing latency 50  mean_bacc: 0.5594114894114894
# Processing latency 51  mean_bacc: 0.5601994851994851
#   New best score found: 0.560
# Processing latency 52  mean_bacc: 0.5493238855738856
# Processing latency 53  mean_bacc: 0.5503221890721891
# Processing latency 54  mean_bacc: 0.5438124488124487
# Processing latency 55  mean_bacc: 0.5368567918567917
# Processing latency 56  mean_bacc: 0.5348751023751024
# Processing latency 57  mean_bacc: 0.5439570902070903
# Processing latency 58  mean_bacc: 0.5728937053937054
#   New best score found: 0.573
# Processing latency 59  mean_bacc: 0.5889880952380953
#   New best score found: 0.589
# Processing latency 60  mean_bacc: 0.5800770738270737
# Processing latency 61  mean_bacc: 0.5810263835263836
# Processing latency 62  mean_bacc: 0.5621482683982684
# Processing latency 63  mean_bacc: 0.5602084064584065
# Processing latency 64  mean_bacc: 0.5664989177489177
# Processing latency 65  mean_bacc: 0.5755007605007605
# Processing latency 66  mean_bacc: 0.5610845910845911
# Processing latency 67  mean_bacc: 0.5845823095823095
# Processing latency 68  mean_bacc: 0.586303235053235
# Processing latency 69  mean_bacc: 0.5882999882999884
# Processing latency 70  mean_bacc: 0.6035421785421786
#   New best score found: 0.604
# Processing latency 71  mean_bacc: 0.6144426406926407
#   New best score found: 0.614
# Processing latency 72  mean_bacc: 0.6260734760734761
#   New best score found: 0.626
# Processing latency 73  mean_bacc: 0.6295960570960571
#   New best score found: 0.630
# Processing latency 74  mean_bacc: 0.6026164151164151
# Processing latency 75  mean_bacc: 0.6251232888732888
# Processing latency 76  mean_bacc: 0.6233619983619982
# Processing latency 77  mean_bacc: 0.6593592781092782
#   New best score found: 0.659
# Processing latency 78  mean_bacc: 0.6792286767286767
#   New best score found: 0.679
# Processing latency 79  mean_bacc: 0.6792449104949105
#   New best score found: 0.679
# Processing latency 80  mean_bacc: 0.6639124839124839
# Processing latency 81  mean_bacc: 0.6621190183690182
# Processing latency 82  mean_bacc: 0.670235608985609
# Processing latency 83  mean_bacc: 0.6738795776295776
# Processing latency 84  mean_bacc: 0.6802021177021178
#   New best score found: 0.680
# Processing latency 85  mean_bacc: 0.6873772961272961
#   New best score found: 0.687
# Processing latency 86  mean_bacc: 0.6900147712647713
#   New best score found: 0.690
# Processing latency 87  mean_bacc: 0.6792275067275068
# Processing latency 88  mean_bacc: 0.6828964841464842
# Processing latency 89  mean_bacc: 0.6684166959166958
# Processing latency 90  mean_bacc: 0.6819869544869546
# Processing latency 91  mean_bacc: 0.682035802035802
# Processing latency 92  mean_bacc: 0.6765495202995204
# Processing latency 93  mean_bacc: 0.690022815022815
#   New best score found: 0.690
# Processing latency 94  mean_bacc: 0.702627968877969
#   New best score found: 0.703
# Processing latency 95  mean_bacc: 0.7143641043641044
#   New best score found: 0.714
# Processing latency 96  mean_bacc: 0.7259788522288523
#   New best score found: 0.726
# Processing latency 97  mean_bacc: 0.7277645665145664
#   New best score found: 0.728
# Processing latency 98  mean_bacc: 0.723309202059202
# Processing latency 99  mean_bacc: 0.7115805253305254
# Processing latency 100  mean_bacc: 0.6908592196092196
# Processing latency 101  mean_bacc: 0.6692939042939043
# Processing latency 102  mean_bacc: 0.670170088920089
# Processing latency 103  mean_bacc: 0.6594400081900081
# Processing latency 104  mean_bacc: 0.6523221598221598
# Processing latency 105  mean_bacc: 0.6512748625248624
# Processing latency 106  mean_bacc: 0.6512584825084826
# Processing latency 107  mean_bacc: 0.6422249034749035
# Processing latency 108  mean_bacc: 0.6368842868842869
# Processing latency 109  mean_bacc: 0.6370222007722008
# Processing latency 110  mean_bacc: 0.6360325260325261
# Processing latency 111  mean_bacc: 0.6297822335322335
# Processing latency 112  mean_bacc: 0.6288321925821926
# Processing latency 113  mean_bacc: 0.6423135310635312
# Processing latency 114  mean_bacc: 0.6377282964782965
# Processing latency 115  mean_bacc: 0.6269173394173395
# Processing latency 116  mean_bacc: 0.613483970983971
# Processing latency 117  mean_bacc: 0.5891593541593542
# Processing latency 118  mean_bacc: 0.5999629987129987
# Processing latency 119  mean_bacc: 0.6016507254007253
# Processing latency 120  mean_bacc: 0.625059085059085
# Processing latency 121  mean_bacc: 0.6305377617877618
# Processing latency 122  mean_bacc: 0.5936324148824148
# Processing latency 123  mean_bacc: 0.6378188253188253
# Processing latency 124  mean_bacc: 0.6080472680472682
# Processing latency 125  mean_bacc: 0.6179248566748567
# Processing latency 126  mean_bacc: 0.6279485491985491
# Processing latency 127  mean_bacc: 0.6216012928512928
# Processing latency 128  mean_bacc: 0.6360408622908623
# Processing latency 129  mean_bacc: 0.622567275067275
# Processing latency 130  mean_bacc: 0.5963754826254826
# Processing latency 131  mean_bacc: 0.6036477711477712
# Processing latency 132  mean_bacc: 0.5883722358722359
# Processing latency 133  mean_bacc: 0.5990860828360829
# Processing latency 134  mean_bacc: 0.5864806364806365
# Processing latency 135  mean_bacc: 0.5971943371943372
# Processing latency 136  mean_bacc: 0.6396038083538084
# Processing latency 137  mean_bacc: 0.6314468526968527
# Processing latency 138  mean_bacc: 0.643978588978589
# Processing latency 139  mean_bacc: 0.6341824616824616
# Processing latency 140  mean_bacc: 0.6576386451386451
# Processing latency 141  mean_bacc: 0.6504312916812917
# Processing latency 142  mean_bacc: 0.6739689364689365
# Processing latency 143  mean_bacc: 0.6703005440505441
# Processing latency 144  mean_bacc: 0.6874096174096174
# Processing latency 145  mean_bacc: 0.691045981045981
# Processing latency 146  mean_bacc: 0.7126765239265239
# Processing latency 147  mean_bacc: 0.7162480987480988
# Processing latency 148  mean_bacc: 0.7288604188604187
#   New best score found: 0.729
# Processing latency 149  mean_bacc: 0.705453082953083
# Processing latency 150  mean_bacc: 0.7162397624897625
# Processing latency 151  mean_bacc: 0.7189016614016615
# Processing latency 152  mean_bacc: 0.700916110916111
# Processing latency 153  mean_bacc: 0.7008666783666784
# Processing latency 154  mean_bacc: 0.6827748040248041
# Processing latency 155  mean_bacc: 0.6602524277524278
# Processing latency 156  mean_bacc: 0.6666725166725167
# Processing latency 157  mean_bacc: 0.6541165028665028
# Processing latency 158  mean_bacc: 0.634255733005733
# Processing latency 159  mean_bacc: 0.6459185971685972
# Processing latency 160  mean_bacc: 0.6152791915291915
# Processing latency 161  mean_bacc: 0.628906048906049
# Processing latency 162  mean_bacc: 0.6324121036621037
# Processing latency 163  mean_bacc: 0.6458861296361297
# Processing latency 164  mean_bacc: 0.647720983970984
# Processing latency 165  mean_bacc: 0.6332496782496783
# Processing latency 166  mean_bacc: 0.6225359775359776
# Processing latency 167  mean_bacc: 0.615448987948988
# Processing latency 168  mean_bacc: 0.6305779805779806
# Processing latency 169  mean_bacc: 0.6261384111384112
# Processing latency 170  mean_bacc: 0.6388244413244413
# Processing latency 171  mean_bacc: 0.6378833216333216
# Processing latency 172  mean_bacc: 0.628915408915409
# Processing latency 173  mean_bacc: 0.6154004329004329
# Processing latency 174  mean_bacc: 0.6072592722592722
# Processing latency 175  mean_bacc: 0.5892010354510355
# Processing latency 176  mean_bacc: 0.5685527085527085
# Processing latency 177  mean_bacc: 0.5874799637299637
# Processing latency 178  mean_bacc: 0.574859161109161
# Processing latency 179  mean_bacc: 0.5595511583011583
# Processing latency 180  mean_bacc: 0.5450713700713701
# Processing latency 181  mean_bacc: 0.55505499005499
# Processing latency 182  mean_bacc: 0.5722054522054523
# Processing latency 183  mean_bacc: 0.5703221890721891
# Processing latency 184  mean_bacc: 0.5685035685035685
# Processing latency 185  mean_bacc: 0.5243174505674506
# Processing latency 186  mean_bacc: 0.5423363460863461
# Processing latency 187  mean_bacc: 0.5405339592839592
# Processing latency 188  mean_bacc: 0.5514098514098513
# Processing latency 189  mean_bacc: 0.5396994559494559
# Processing latency 190  mean_bacc: 0.5540808178308179
# Processing latency 191  mean_bacc: 0.5054309991809992
# Processing latency 192  mean_bacc: 0.5273046098046098
# Processing latency 193  mean_bacc: 0.5056573944073944
# Processing latency 194  mean_bacc: 0.5111524511524511
# Processing latency 195  mean_bacc: 0.5311836024336024
# Processing latency 196  mean_bacc: 0.5392358429858429
# Processing latency 197  mean_bacc: 0.5459403884403884
# Processing latency 198  mean_bacc: 0.5468497718497718
# Processing latency 199  mean_bacc: 0.5117289692289692
#
# Results Summary:
# Best latency: 148
# Relative to press: 0.2400 s
# Cross-validation balanced accuracy: 0.729

# %%
# Re-fit on full training set (85 %) with best latency
X_train_best = X_train[:, best_lat, :]
X_test_best  = X_test[:,  best_lat, :]

ridge_pipe.fit(X_train_best, y_train)
print('DONE TRAINING')
print(f'Alpha: {ridge_pipe.named_steps["ridgeclassifiercv"].alpha_}')
# Out:
# DONE TRAINING
# Alpha: 1.0

# %%
# Testing the model
test_score = ridge_pipe.score(X_test_best, y_test)
print(f"Test set balanced accuracy: {test_score:.3f}")

predictions = ridge_pipe.predict(X_test_best)
print("\nClassification Report:")
print(classification_report(y_test, predictions))
# Out:
# Test set balanced accuracy: 0.773
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.76      0.79      0.78       139
#            2       0.78      0.76      0.77       139
#
#     accuracy                           0.77       278
#    macro avg       0.77      0.77      0.77       278
# weighted avg       0.77      0.77      0.77       278

# %%
# Feature importance
channel_names = meta_data['channel_names']
coefs = list(ridge_pipe.named_steps['ridgeclassifiercv'].coef_)

sorted_coefs = sorted(list(zip(channel_names, coefs)), key=lambda x: abs(x[1]), reverse=True)

for channel, coef in sorted_coefs:
    print(f"{channel}: {coef:.3f}")
# Out:
# O2: 0.683
# T5: -0.531
# C4: 0.166
# F4: -0.086
# F8: -0.085
# O1: -0.083
# F7: 0.082
# Pz: -0.075
# P4: -0.073
# F3: -0.065
# T6: 0.063
# Fp2: -0.048
# P3: 0.044
# Fp1: 0.043
# Cz: 0.043
# T3: -0.040
# T4: 0.017
# Fz: -0.004
# C3: -0.003

# %%
# CV scores of all latencies
mean_cv_scores = [cv_scores.mean() for cv_scores in all_scores.values()]

# Plot CV scores as bar chart
plt.figure(figsize=(12, 6))
plt.bar(range(len(mean_cv_scores)), mean_cv_scores)
plt.xlabel('Time Point')
plt.ylabel('Mean CV Score')
plt.title('Cross-Validation Scores Across Time Points')
plt.grid(True, alpha=0.3)
plt.show()
